# %% [markdown]
# # 1.Data Preparation / Pre-processing

# %%
import pandas as pd

# %%
# verses = pd.read_csv('verses.csv')
# data = pd.read_csv('file1.csv', on_bad_lines='skip')
df = pd.read_csv('verses.csv', sep='|', header=[0])
df.head(10)
# Out:
#   verse                                            context
# 0   1:1  The Revelation of Jesus Christ, which God gave...
# 1   1:2  Who barerecord of the word of God, and of the ...
# 2   1:3  Blessed is he that readeth, and they that hear...
# 3   1:4  John to the seven churches which are in Asia: ...
# 4   1:5  And from JesusChrist, who is the faithful witn...
# 5   1:6  And hath made uskings and priests unto God and...
# 6   1:7  Behold, he cometh with clouds; and every eye s...
# 7   1:8  I am Alpha and Omega, the beginning and the en...
# 8   1:9  I John, who also am your brother, and companio...
# 9  1:10                    I was in the Spirit on the Lord

# %% [markdown]
# ## 1.1 Remove Punctuation

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#define punctuation
punct = string.punctuation
text = "Can you use a @smiley face, 'emoji' as a : period instead?"
no_punct = ""

for char in text:
    if char not in punct:
        no_punct = no_punct + char
        
# display the unpuncted string
no_punct
# Out:
# 'Can you use a smiley face emoji as a  period instead'

# %%
def remove_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct

df['context_nopunc'] = df['context'].apply(lambda x: remove_punct(x))
df.head()
# Out:
#   verse                                            context  \
# 0   1:1  The Revelation of Jesus Christ, which God gave...
# 1   1:2  Who barerecord of the word of God, and of the ...
# 2   1:3  Blessed is he that readeth, and they that hear...
# 3   1:4  John to the seven churches which are in Asia: ...
# 4   1:5  And from JesusChrist, who is the faithful witn...
#
#                                       context_nopunc
# 0  The Revelation of Jesus Christ which God gave ...
# 1  Who barerecord of the word of God and of the t...
# 2  Blessed is he that readeth and they that hear ...
# 3  John to the seven churches which are in Asia G...
# 4  And from JesusChrist who is the faithful witne...

# %% [markdown]
# ## 1.2 Lowercase

# %%
'nlp'=='NLP'.lower()
# Out:
# True

# %%
#add lower to teh remove_punc function

#list comprhansion 
#lambda function
#adding join to join chars into words 
def remove_punct(text):
    
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct

df['context_nopunc'] = df['context'].apply(lambda x: remove_punct(x.lower()))
df.head()
# Out:
#   verse                                            context  \
# 0   1:1  The Revelation of Jesus Christ, which God gave...
# 1   1:2  Who barerecord of the word of God, and of the ...
# 2   1:3  Blessed is he that readeth, and they that hear...
# 3   1:4  John to the seven churches which are in Asia: ...
# 4   1:5  And from JesusChrist, who is the faithful witn...
#
#                                       context_nopunc
# 0  the revelation of jesus christ which god gave ...
# 1  who barerecord of the word of god and of the t...
# 2  blessed is he that readeth and they that hear ...
# 3  john to the seven churches which are in asia g...
# 4  and from jesuschrist who is the faithful witne...

# %% [markdown]
# ## 1.3 Tokenization

# %%
import nltk
# nltk.download('punkt')
from nltk.tokenize import word_tokenize
import re

# %%
text = "Can you use a smiley face emoji as a  period instead"
tokens = re.split('\W+', text)
tokens
# Out:
# ['Can',
#  'you',
#  'use',
#  'a',
#  'smiley',
#  'face',
#  'emoji',
#  'as',
#  'a',
#  'period',
#  'instead']

# %%
def tokenize(text):
    tokens = word_tokenize(text)
    return tokens
df['context_tokenized'] = df['context_nopunc'].apply(lambda x: tokenize(x))
df.head()
# Out:
#   verse                                            context  \
# 0   1:1  The Revelation of Jesus Christ, which God gave...
# 1   1:2  Who barerecord of the word of God, and of the ...
# 2   1:3  Blessed is he that readeth, and they that hear...
# 3   1:4  John to the seven churches which are in Asia: ...
# 4   1:5  And from JesusChrist, who is the faithful witn...
#
#                                       context_nopunc  \
# 0  the revelation of jesus christ which god gave ...
# 1  who barerecord of the word of god and of the t...
# 2  blessed is he that readeth and they that hear ...
# 3  john to the seven churches which are in asia g...
# 4  and from jesuschrist who is the faithful witne...
#
#                                    context_tokenized
# 0  [the, revelation, of, jesus, christ, which, go...
# 1  [who, barerecord, of, the, word, of, god, and,...
# 2  [blessed, is, he, that, readeth, and, they, th...
# 3  [john, to, the, seven, churches, which, are, i...
# 4  [and, from, jesuschrist, who, is, the, faithfu...

# %% [markdown]
# ## 1.4 stop words

# %%
import nltk
# nltk.download('stopwords')
from nltk.corpus import stopwords

# %%
stopwords_En = nltk.corpus.stopwords.words('english')

# %%
stopwords_En
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopwords_En]
    return text

df['context_nostop'] = df['context_tokenized'].apply(lambda x: remove_stopwords(x))
df.head()
# Out:
#   verse                                            context  \
# 0   1:1  The Revelation of Jesus Christ, which God gave...
# 1   1:2  Who barerecord of the word of God, and of the ...
# 2   1:3  Blessed is he that readeth, and they that hear...
# 3   1:4  John to the seven churches which are in Asia: ...
# 4   1:5  And from JesusChrist, who is the faithful witn...
#
#                                       context_nopunc  \
# 0  the revelation of jesus christ which god gave ...
# 1  who barerecord of the word of god and of the t...
# 2  blessed is he that readeth and they that hear ...
# 3  john to the seven churches which are in asia g...
# 4  and from jesuschrist who is the faithful witne...
#
#                                    context_tokenized  \
# 0  [the, revelation, of, jesus, christ, which, go...
# 1  [who, barerecord, of, the, word, of, god, and,...
# 2  [blessed, is, he, that, readeth, and, they, th...
# 3  [john, to, the, seven, churches, which, are, i...
# 4  [and, from, jesuschrist, who, is, the, faithfu...
#
#                                       context_nostop
# 0  [revelation, jesus, christ, god, gave, unto, s...
# 1  [barerecord, word, god, testimony, jesus, chri...
# 2  [blessed, readeth, hear, words, thisprophecy, ...
# 3  [john, seven, churches, asia, grace, unto, you...
# 4  [jesuschrist, faithful, witness, first, begott...

# %% [markdown]
# ## 1.4 Stemming

# %%
import nltk
ps= nltk.PorterStemmer();

# %%
dir(ps)
# Out:
# ['MARTIN_EXTENSIONS',
#  'NLTK_EXTENSIONS',
#  'ORIGINAL_ALGORITHM',
#  '__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_apply_rule_list',
#  '_contains_vowel',
#  '_ends_cvc',
#  '_ends_double_consonant',
#  '_has_positive_measure',
#  '_is_consonant',
#  '_measure',
#  '_replace_suffix',
#  '_step1a',
#  '_step1b',
#  '_step1c',
#  '_step2',
#  '_step3',
#  '_step4',
#  '_step5a',
#  '_step5b',
#  'mode',
#  'pool',
#  'stem',
#  'vowels']

# %%
print(ps.stem('play'))
print(ps.stem('playing'))
print(ps.stem('played'))
print(ps.stem('plays'))
# Out:
# play
# play
# play
# play

# %%
#Over-Steming 
#Over-steaming occurs when two words are stemmed from the same root of different stems. 

print(ps.stem('universal'))
print(ps.stem('university'))
print(ps.stem('universe'))
# Out:
# univers
# univers
# univers

# %%
#Under-Steming
#Under-stemming occurs when two words are stemmed from the same root of not a different stems

print(ps.stem('alumnus'))
print(ps.stem('alumni'))
print(ps.stem('alumnae'))
# Out:
# alumnu
# alumni
# alumna

# %%
def stemming(tokenized_text):
    text = [ps.stem(word) for word in tokenized_text]
    return text

df['context_stemmed'] = df['context_nostop'].apply(lambda x: stemming(x))
df.head(10)
# Out:
#   verse                                            context  \
# 0   1:1  The Revelation of Jesus Christ, which God gave...
# 1   1:2  Who barerecord of the word of God, and of the ...
# 2   1:3  Blessed is he that readeth, and they that hear...
# 3   1:4  John to the seven churches which are in Asia: ...
# 4   1:5  And from JesusChrist, who is the faithful witn...
# 5   1:6  And hath made uskings and priests unto God and...
# 6   1:7  Behold, he cometh with clouds; and every eye s...
# 7   1:8  I am Alpha and Omega, the beginning and the en...
# 8   1:9  I John, who also am your brother, and companio...
# 9  1:10                    I was in the Spirit on the Lord
#
#                                       context_nopunc  \
# 0  the revelation of jesus christ which god gave ...
# 1  who barerecord of the word of god and of the t...
# 2  blessed is he that readeth and they that hear ...
# 3  john to the seven churches which are in asia g...
# 4  and from jesuschrist who is the faithful witne...
# 5  and hath made uskings and priests unto god and...
# 6  behold he cometh with clouds and every eye sha...
# 7  i am alpha and omega the beginning and the end...
# 8  i john who also am your brother and companion ...
# 9                    i was in the spirit on the lord
#
#                                    context_tokenized  \
# 0  [the, revelation, of, jesus, christ, which, go...
# 1  [who, barerecord, of, the, word, of, god, and,...
# 2  [blessed, is, he, that, readeth, and, they, th...
# 3  [john, to, the, seven, churches, which, are, i...
# 4  [and, from, jesuschrist, who, is, the, faithfu...
# 5  [and, hath, made, uskings, and, priests, unto,...
# 6  [behold, he, cometh, with, clouds, and, every,...
# 7  [i, am, alpha, and, omega, the, beginning, and...
# 8  [i, john, who, also, am, your, brother, and, c...
# 9           [i, was, in, the, spirit, on, the, lord]
#
#                                       context_nostop  \
# 0  [revelation, jesus, christ, god, gave, unto, s...
# 1  [barerecord, word, god, testimony, jesus, chri...
# 2  [blessed, readeth, hear, words, thisprophecy, ...
# 3  [john, seven, churches, asia, grace, unto, you...
# 4  [jesuschrist, faithful, witness, first, begott...
# 5  [hath, made, uskings, priests, unto, god, fath...
# 6  [behold, cometh, clouds, every, eye, shall, se...
# 7  [alpha, omega, beginning, ending, saith, thelo...
# 8  [john, also, brother, companion, tribulationan...
# 9                                     [spirit, lord]
#
#                                      context_stemmed
# 0  [revel, jesu, christ, god, gave, unto, shewunt...
# 1  [barerecord, word, god, testimoni, jesu, chris...
# 2  [bless, readeth, hear, word, thispropheci, kee...
# 3  [john, seven, church, asia, grace, unto, youan...
# 4  [jesuschrist, faith, wit, first, begotten, the...
# 5  [hath, made, usk, priest, unto, god, father, g...
# 6  [behold, cometh, cloud, everi, eye, shall, see...
# 7  [alpha, omega, begin, end, saith, thelord, com...
# 8  [john, also, brother, companion, tribulationan...
# 9                                     [spirit, lord]

# %% [markdown]
# ## 1.4 Lemmatization

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Sc\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Sc\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nltk

wn = nltk.WordNetLemmatizer()
ps = nltk.PorterStemmer()

# %%
dir(wn)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'lemmatize']

# %%
print(wn.lemmatize('universal'))
print(wn.lemmatize('university'))
print(wn.lemmatize('universe'))
# Out:
# universal
# university
# universe

# %%
print(wn.lemmatize('alumnus'))
print(wn.lemmatize('alumni'))
print(wn.lemmatize('alumnae'))
# Out:
# alumnus
# alumnus
# alumna

# %%
def lemmatizing(tokenized_text):
    text = [wn.lemmatize(word) for word in tokenized_text]
    return text

df['context_lemmatized'] = df['context_nostop'].apply(lambda x: lemmatizing(x))

df.head(10)
# Out:
#   verse                                            context  \
# 0   1:1  The Revelation of Jesus Christ, which God gave...
# 1   1:2  Who barerecord of the word of God, and of the ...
# 2   1:3  Blessed is he that readeth, and they that hear...
# 3   1:4  John to the seven churches which are in Asia: ...
# 4   1:5  And from JesusChrist, who is the faithful witn...
# 5   1:6  And hath made uskings and priests unto God and...
# 6   1:7  Behold, he cometh with clouds; and every eye s...
# 7   1:8  I am Alpha and Omega, the beginning and the en...
# 8   1:9  I John, who also am your brother, and companio...
# 9  1:10                    I was in the Spirit on the Lord
#
#                                       context_nopunc  \
# 0  the revelation of jesus christ which god gave ...
# 1  who barerecord of the word of god and of the t...
# 2  blessed is he that readeth and they that hear ...
# 3  john to the seven churches which are in asia g...
# 4  and from jesuschrist who is the faithful witne...
# 5  and hath made uskings and priests unto god and...
# 6  behold he cometh with clouds and every eye sha...
# 7  i am alpha and omega the beginning and the end...
# 8  i john who also am your brother and companion ...
# 9                    i was in the spirit on the lord
#
#                                    context_tokenized  \
# 0  [the, revelation, of, jesus, christ, which, go...
# 1  [who, barerecord, of, the, word, of, god, and,...
# 2  [blessed, is, he, that, readeth, and, they, th...
# 3  [john, to, the, seven, churches, which, are, i...
# 4  [and, from, jesuschrist, who, is, the, faithfu...
# 5  [and, hath, made, uskings, and, priests, unto,...
# 6  [behold, he, cometh, with, clouds, and, every,...
# 7  [i, am, alpha, and, omega, the, beginning, and...
# 8  [i, john, who, also, am, your, brother, and, c...
# 9           [i, was, in, the, spirit, on, the, lord]
#
#                                       context_nostop  \
# 0  [revelation, jesus, christ, god, gave, unto, s...
# 1  [barerecord, word, god, testimony, jesus, chri...
# 2  [blessed, readeth, hear, words, thisprophecy, ...
# 3  [john, seven, churches, asia, grace, unto, you...
# 4  [jesuschrist, faithful, witness, first, begott...
# 5  [hath, made, uskings, priests, unto, god, fath...
# 6  [behold, cometh, clouds, every, eye, shall, se...
# 7  [alpha, omega, beginning, ending, saith, thelo...
# 8  [john, also, brother, companion, tribulationan...
# 9                                     [spirit, lord]
#
#                                      context_stemmed  \
# 0  [revel, jesu, christ, god, gave, unto, shewunt...
# 1  [barerecord, word, god, testimoni, jesu, chris...
# 2  [bless, readeth, hear, word, thispropheci, kee...
# 3  [john, seven, church, asia, grace, unto, youan...
# 4  [jesuschrist, faith, wit, first, begotten, the...
# 5  [hath, made, usk, priest, unto, god, father, g...
# 6  [behold, cometh, cloud, everi, eye, shall, see...
# 7  [alpha, omega, begin, end, saith, thelord, com...
# 8  [john, also, brother, companion, tribulationan...
# 9                                     [spirit, lord]
#
#                                   context_lemmatized
# 0  [revelation, jesus, christ, god, gave, unto, s...
# 1  [barerecord, word, god, testimony, jesus, chri...
# 2  [blessed, readeth, hear, word, thisprophecy, k...
# 3  [john, seven, church, asia, grace, unto, youan...
# 4  [jesuschrist, faithful, witness, first, begott...
# 5  [hath, made, uskings, priest, unto, god, fathe...
# 6  [behold, cometh, cloud, every, eye, shall, see...
# 7  [alpha, omega, beginning, ending, saith, thelo...
# 8  [john, also, brother, companion, tribulationan...
# 9                                     [spirit, lord]

# %% [markdown]
# ## Zipf's Law

# %%
def terms_frequency (list):
    dictionary={}      # store terms in a dictionary (key,value)
    counted_list=[]      # fill in this list with words that are already counted
    for term in list:
        if term not in counted_list:
            freq=list.count(term)
            dictionary[term]=freq
            counted_list.append(term)

    return sorted(dictionary.items(), key=lambda x:x[1], reverse=True)

# %%
print(len(df), df['context_stemmed'][0])
# Out:
# 4517 ['revel', 'jesu', 'christ', 'god', 'gave', 'unto', 'shewunto', 'servant', 'thing', 'must', 'shortli', 'come', 'pass', 'sentand', 'signifi', 'angel', 'unto', 'servant', 'john']

# %%
list = []
for i in range(len(df)):
    list += df['context_stemmed'][i]
terms_freq = terms_frequency(list)
terms_freq
# Out:
# [('shall', 1233),
#  ('lord', 976),
#  ('unto', 920),
#  ('thi', 730),
#  ('thou', 684),
#  ('god', 612),
#  ('thee', 442),
#  ('ye', 408),
#  ('upon', 332),
#  ('said', 278),
#  ('hath', 277),
#  ('come', 274),
#  ('man', 271),
#  ('day', 268),
#  ('say', 267),
#  ('let', 264),
#  ('one', 257),
#  ('peopl', 218),
#  ('hand', 213),
#  ('saith', 213),
#  ('also', 210),
#  ('earth', 203),
#  ('land', 203),
#  ('israel', 192),
#  ('thing', 189),
#  ('us', 185),
#  ('hast', 185),
#  ('name', 170),
#  ('great', 169),
#  ('son', 166),
#  ('behold', 161),
#  ('hous', 156),
#  ('word', 154),
#  ('came', 152),
#  ('heaven', 149),
#  ('shalt', 145),
#  ('go', 145),
#  ('men', 145),
#  ('like', 144),
#  ('jesu', 142),
#  ('king', 142),
#  ('even', 141),
#  ('made', 135),
#  ('way', 135),
#  ('ever', 133),
#  ('make', 130),
#  ('therefor', 128),
#  ('holi', 127),
#  ('prais', 124),
#  ('work', 122),
#  ('children', 122),
#  ('forth', 122),
#  ('give', 120),
#  ('know', 119),
#  ('thu', 118),
#  ('among', 117),
#  ('thereof', 116),
#  ('offer', 116),
#  ('citi', 115),
#  ('neither', 115),
#  ('side', 115),
#  ('gate', 114),
#  ('everi', 113),
#  ('heart', 113),
#  ('father', 111),
#  ('may', 108),
#  ('art', 106),
#  ('thine', 101),
#  ('thousand', 100),
#  ('brought', 98),
#  ('nation', 96),
#  ('see', 95),
#  ('water', 95),
#  ('saw', 94),
#  ('priest', 94),
#  ('beast', 94),
#  ('servant', 93),
#  ('voic', 91),
#  ('place', 90),
#  ('heard', 90),
#  ('away', 90),
#  ('call', 89),
#  ('bring', 89),
#  ('merci', 88),
#  ('soul', 88),
#  ('accord', 87),
#  ('put', 87),
#  ('bless', 86),
#  ('fear', 84),
#  ('yet', 84),
#  ('mani', 83),
#  ('sea', 83),
#  ('mine', 83),
#  ('angel', 82),
#  ('year', 82),
#  ('set', 80),
#  ('fire', 79),
#  ('speak', 79),
#  ('command', 79),
#  ('caus', 79),
#  ('high', 79),
#  ('seven', 78),
#  ('dwell', 78),
#  ('take', 78),
#  ('good', 78),
#  ('cubit', 78),
#  ('sword', 76),
#  ('hear', 75),
#  ('eye', 75),
#  ('paul', 75),
#  ('pass', 74),
#  ('went', 74),
#  ('law', 74),
#  ('toward', 74),
#  ('glori', 73),
#  ('ofth', 73),
#  ('sin', 72),
#  ('two', 72),
#  ('babylon', 72),
#  ('spirit', 71),
#  ('mouth', 69),
#  ('judgment', 69),
#  ('cri', 69),
#  ('christ', 68),
#  ('round', 68),
#  ('measur', 68),
#  ('live', 68),
#  ('enemi', 68),
#  ('face', 67),
#  ('blood', 66),
#  ('turn', 66),
#  ('midst', 66),
#  ('death', 66),
#  ('cast', 65),
#  ('five', 65),
#  ('dead', 64),
#  ('open', 64),
#  ('hundr', 63),
#  ('egypt', 63),
#  ('deliv', 63),
#  ('time', 61),
#  ('anoth', 60),
#  ('togeth', 60),
#  ('keep', 59),
#  ('took', 59),
#  ('done', 59),
#  ('gave', 58),
#  ('right', 57),
#  ('love', 57),
#  ('jerusalem', 57),
#  ('rejoic', 57),
#  ('four', 56),
#  ('given', 56),
#  ('righteous', 56),
#  ('found', 55),
#  ('shew', 55),
#  ('throne', 54),
#  ('yea', 54),
#  ('thelord', 53),
#  ('life', 53),
#  ('rememb', 53),
#  ('eat', 53),
#  ('save', 53),
#  ('believ', 53),
#  ('mountain', 53),
#  ('answer', 53),
#  ('head', 52),
#  ('fall', 52),
#  ('sent', 52),
#  ('wick', 52),
#  ('long', 52),
#  ('judg', 52),
#  ('destroy', 52),
#  ('iniqu', 52),
#  ('spake', 51),
#  ('east', 50),
#  ('first', 49),
#  ('power', 49),
#  ('tree', 49),
#  ('lamb', 49),
#  ('templ', 48),
#  ('would', 48),
#  ('might', 48),
#  ('court', 48),
#  ('peac', 47),
#  ('laid', 47),
#  ('chief', 47),
#  ('princ', 46),
#  ('jew', 46),
#  ('depart', 46),
#  ('sing', 46),
#  ('without', 45),
#  ('die', 45),
#  ('three', 45),
#  ('twenti', 44),
#  ('part', 44),
#  ('faith', 43),
#  ('strength', 43),
#  ('receiv', 43),
#  ('mighti', 43),
#  ('multitud', 43),
#  ('light', 43),
#  ('prophet', 43),
#  ('jacob', 43),
#  ('desol', 43),
#  ('flesh', 42),
#  ('david', 42),
#  ('salvat', 42),
#  ('flock', 42),
#  ('chamber', 42),
#  ('none', 41),
#  ('stood', 41),
#  ('continu', 41),
#  ('gather', 41),
#  ('inherit', 41),
#  ('world', 40),
#  ('stand', 40),
#  ('look', 40),
#  ('month', 40),
#  ('righteou', 40),
#  ('meat', 40),
#  ('daughter', 40),
#  ('ear', 39),
#  ('littl', 39),
#  ('drink', 39),
#  ('brethren', 39),
#  ('sure', 39),
#  ('twelv', 39),
#  ('host', 39),
#  ('feet', 38),
#  ('worship', 38),
#  ('river', 38),
#  ('sanctuari', 38),
#  ('testimoni', 37),
#  ('stone', 37),
#  ('taken', 37),
#  ('coven', 37),
#  ('cut', 37),
#  ('heathen', 37),
#  ('full', 36),
#  ('slain', 36),
#  ('wrath', 36),
#  ('joseph', 36),
#  ('inth', 36),
#  ('evil', 36),
#  ('mose', 36),
#  ('wall', 36),
#  ('spoken', 36),
#  ('lift', 36),
#  ('cometh', 35),
#  ('end', 35),
#  ('door', 35),
#  ('night', 35),
#  ('fill', 35),
#  ('enter', 35),
#  ('captiv', 35),
#  ('joy', 35),
#  ('field', 35),
#  ('afflict', 34),
#  ('truth', 34),
#  ('wast', 34),
#  ('bread', 34),
#  ('border', 34),
#  ('zion', 34),
#  ('written', 33),
#  ('kingdom', 33),
#  ('ten', 33),
#  ('tribe', 33),
#  ('prepar', 33),
#  ('dark', 33),
#  ('return', 33),
#  ('wilder', 32),
#  ('south', 32),
#  ('peter', 32),
#  ('therein', 31),
#  ('cloth', 31),
#  ('fell', 31),
#  ('seen', 31),
#  ('hold', 31),
#  ('wherefor', 31),
#  ('sun', 31),
#  ('gener', 31),
#  ('inhabit', 31),
#  ('whose', 31),
#  ('seed', 31),
#  ('pharaoh', 31),
#  ('wonder', 31),
#  ('north', 31),
#  ('book', 30),
#  ('shame', 30),
#  ('third', 30),
#  ('seal', 30),
#  ('reproach', 30),
#  ('rais', 30),
#  ('glad', 30),
#  ('length', 30),
#  ('troubl', 30),
#  ('broken', 30),
#  ('judah', 30),
#  ('cover', 30),
#  ('sound', 29),
#  ('new', 29),
#  ('known', 29),
#  ('lie', 29),
#  ('tongu', 29),
#  ('number', 29),
#  ('whole', 29),
#  ('follow', 29),
#  ('captain', 29),
#  ('rise', 29),
#  ('old', 29),
#  ('fruit', 29),
#  ('breadth', 29),
#  ('anger', 29),
#  ('portion', 29),
#  ('wit', 28),
#  ('burn', 28),
#  ('rest', 28),
#  ('till', 28),
#  ('walk', 28),
#  ('gold', 28),
#  ('desir', 28),
#  ('concern', 28),
#  ('altar', 28),
#  ('burnt', 28),
#  ('seek', 28),
#  ('build', 28),
#  ('everlast', 28),
#  ('write', 27),
#  ('saint', 27),
#  ('within', 27),
#  ('honour', 27),
#  ('lo', 27),
#  ('wind', 27),
#  ('help', 27),
#  ('though', 27),
#  ('cloud', 26),
#  ('hate', 26),
#  ('woman', 26),
#  ('poor', 26),
#  ('sat', 26),
#  ('hope', 26),
#  ('pit', 26),
#  ('declar', 26),
#  ('young', 26),
#  ('prison', 25),
#  ('hour', 25),
#  ('thank', 25),
#  ('strong', 25),
#  ('bodi', 25),
#  ('mother', 25),
#  ('left', 25),
#  ('prophesi', 25),
#  ('tabernacl', 25),
#  ('certain', 25),
#  ('minist', 25),
#  ('lay', 25),
#  ('possess', 25),
#  ('smote', 25),
#  ('endureth', 25),
#  ('church', 24),
#  ('second', 24),
#  ('kept', 24),
#  ('serv', 24),
#  ('reed', 24),
#  ('maketh', 24),
#  ('imag', 24),
#  ('garment', 24),
#  ('near', 24),
#  ('far', 24),
#  ('scatter', 24),
#  ('stranger', 24),
#  ('statut', 24),
#  ('post', 24),
#  ('bear', 23),
#  ('sight', 23),
#  ('elder', 23),
#  ('six', 23),
#  ('hors', 23),
#  ('ship', 23),
#  ('utter', 23),
#  ('thought', 23),
#  ('gone', 23),
#  ('countri', 23),
#  ('trust', 23),
#  ('hill', 23),
#  ('presenc', 22),
#  ('understand', 22),
#  ('sit', 22),
#  ('andth', 22),
#  ('much', 22),
#  ('horn', 22),
#  ('forti', 22),
#  ('sacrific', 22),
#  ('carri', 22),
#  ('heal', 22),
#  ('sorrow', 22),
#  ('compass', 21),
#  ('apostl', 21),
#  ('true', 21),
#  ('ask', 21),
#  ('redeem', 21),
#  ('morn', 21),
#  ('break', 21),
#  ('wilt', 21),
#  ('congreg', 21),
#  ('grace', 20),
#  ('send', 20),
#  ('star', 20),
#  ('teach', 20),
#  ('repent', 20),
#  ('suffer', 20),
#  ('idol', 20),
#  ('commit', 20),
#  ('lion', 20),
#  ('prayer', 20),
#  ('oil', 20),
#  ('rock', 20),
#  ('dwelt', 20),
#  ('goeth', 20),
#  ('discipl', 20),
#  ('divid', 20),
#  ('pray', 20),
#  ('thyself', 20),
#  ('youth', 20),
#  ('deep', 20),
#  ('sought', 20),
#  ('selah', 20),
#  ('must', 19),
#  ('labour', 19),
#  ('noth', 19),
#  ('bone', 19),
#  ('leav', 19),
#  ('moon', 19),
#  ('grave', 19),
#  ('becom', 19),
#  ('abomin', 19),
#  ('sheep', 19),
#  ('ofisrael', 19),
#  ('exalt', 19),
#  ('sleep', 19),
#  ('back', 19),
#  ('bow', 19),
#  ('suburb', 19),
#  ('philistin', 19),
#  ('foot', 18),
#  ('perfect', 18),
#  ('born', 18),
#  ('fallen', 18),
#  ('kill', 18),
#  ('fast', 18),
#  ('increas', 18),
#  ('loud', 18),
#  ('wine', 18),
#  ('verili', 18),
#  ('smoke', 18),
#  ('chosen', 18),
#  ('manner', 18),
#  ('devour', 18),
#  ('wherewith', 18),
#  ('plagu', 18),
#  ('war', 18),
#  ('dragon', 18),
#  ('lest', 18),
#  ('pour', 18),
#  ('wherein', 18),
#  ('west', 18),
#  ('wait', 18),
#  ('ram', 18),
#  ('valley', 18),
#  ('asham', 18),
#  ('spoil', 18),
#  ('last', 17),
#  ('doth', 17),
#  ('rich', 17),
#  ('appear', 17),
#  ('beheld', 17),
#  ('hid', 17),
#  ('comfort', 17),
#  ('child', 17),
#  ('dri', 17),
#  ('mount', 17),
#  ('vain', 17),
#  ('habit', 17),
#  ('giveth', 17),
#  ('well', 17),
#  ('plant', 17),
#  ('bullock', 17),
#  ('daili', 17),
#  ('cattl', 17),
#  ('oblat', 17),
#  ('shepherd', 17),
#  ('consum', 17),
#  ('precept', 17),
#  ('broad', 17),
#  ('white', 16),
#  ('whither', 16),
#  ('feed', 16),
#  ('mind', 16),
#  ('silver', 16),
#  ('forev', 16),
#  ('cup', 16),
#  ('gentil', 16),
#  ('perish', 16),
#  ('toth', 16),
#  ('sign', 16),
#  ('sore', 16),
#  ('moreov', 16),
#  ('curs', 16),
#  ('led', 16),
#  ('arm', 16),
#  ('tabl', 16),
#  ('porch', 16),
#  ('ephah', 16),
#  ('moab', 16),
#  ('establish', 16),
#  ('john', 15),
#  ('amen', 15),
#  ('brother', 15),
#  ('except', 15),
#  ('iwil', 15),
#  ('watch', 15),
#  ('trumpet', 15),
#  ('loos', 15),
#  ('wife', 15),
#  ('nois', 15),
#  ('themthat', 15),
#  ('becam', 15),
#  ('corner', 15),
#  ('throughout', 15),
#  ('aros', 15),
#  ('armi', 15),
#  ('small', 15),
#  ('didst', 15),
#  ('bound', 15),
#  ('piec', 15),
#  ('pleasur', 15),
#  ('allth', 15),
#  ('jeremiah', 15),
#  ('ground', 15),
#  ('fifti', 15),
#  ('shekel', 15),
#  ('remov', 15),
#  ('inner', 15),
#  ('food', 15),
#  ('proud', 15),
#  ('liveth', 14),
#  ('evermor', 14),
#  ('wise', 14),
#  ('preach', 14),
#  ('nevertheless', 14),
#  ('defil', 14),
#  ('shut', 14),
#  ('dwelleth', 14),
#  ('testifi', 14),
#  ('song', 14),
#  ('reign', 14),
#  ('charg', 14),
#  ('fulfil', 14),
#  ('move', 14),
#  ('draw', 14),
#  ('grass', 14),
#  ('women', 14),
#  ('battl', 14),
#  ('wood', 14),
#  ('appoint', 14),
#  ('whereof', 14),
#  ('vengeanc', 14),
#  ('accus', 14),
#  ('could', 14),
#  ('sabbath', 14),
#  ('knew', 14),
#  ('fowl', 14),
#  ('height', 14),
#  ('council', 14),
#  ('told', 14),
#  ('favour', 14),
#  ('sanctifi', 14),
#  ('thenc', 14),
#  ('escap', 14),
#  ('fat', 14),
#  ('furi', 14),
#  ('thirti', 14),
#  ('lovingkind', 14),
#  ('goat', 14),
#  ('abl', 13),
#  ('widow', 13),
#  ('knoweth', 13),
#  ('brass', 13),
#  ('pillar', 13),
#  ('mayest', 13),
#  ('creat', 13),
#  ('whosoev', 13),
#  ('foundat', 13),
#  ('ghost', 13),
#  ('assembl', 13),
#  ('reward', 13),
#  ('afar', 13),
#  ('began', 13),
#  ('festu', 13),
#  ('tarri', 13),
#  ('promis', 13),
#  ('stretch', 13),
#  ('levit', 13),
#  ('afraid', 13),
#  ('lip', 13),
#  ('abraham', 13),
#  ('confound', 13),
#  ('forget', 13),
#  ('oppress', 13),
#  ('delight', 13),
#  ('greatli', 13),
#  ('begin', 12),
#  ('crown', 12),
#  ('worthi', 12),
#  ('talk', 12),
#  ('thunder', 12),
#  ('fli', 12),
#  ('epistl', 12),
#  ('shallb', 12),
#  ('readi', 12),
#  ('nigh', 12),
#  ('better', 12),
#  ('woe', 12),
#  ('adversari', 12),
#  ('threescor', 12),
#  ('rain', 12),
#  ('drew', 12),
#  ('rule', 12),
#  ('flood', 12),
#  ('corrupt', 12),
#  ('fromth', 12),
#  ('still', 12),
#  ('ruler', 12),
#  ('sister', 12),
#  ('sick', 12),
#  ('ceas', 12),
#  ('vaniti', 12),
#  ('transgress', 12),
#  ('shield', 12),
#  ('window', 12),
#  ('fail', 12),
#  ('aris', 12),
#  ('aaron', 12),
#  ('galile', 12),
#  ('snare', 12),
#  ('andthey', 11),
#  ('golden', 11),
#  ('hell', 11),
#  ('hurt', 11),
#  ('taught', 11),
#  ('bed', 11),
#  ('deni', 11),
#  ('counsel', 11),
#  ('hither', 11),
#  ('vial', 11),
#  ('season', 11),
#  ('ascend', 11),
#  ('thechildren', 11),
#  ('palm', 11),
#  ('find', 11),
#  ('andshal', 11),
#  ('flee', 11),
#  ('sweet', 11),
#  ('rod', 11),
#  ('refus', 11),
#  ('pain', 11),
#  ('fled', 11),
#  ('wisdom', 11),
#  ('harp', 11),
#  ('persecut', 11),
#  ('rose', 11),
#  ('wax', 11),
#  ('famin', 11),
#  ('utterli', 11),
#  ('compani', 11),
#  ('violenc', 11),
#  ('shine', 11),
#  ('sail', 11),
#  ('theyshal', 11),
#  ('ran', 11),
#  ('band', 11),
#  ('soldier', 11),
#  ('centurion', 11),
#  ('pharise', 11),
#  ('never', 11),
#  ('thoushalt', 11),
#  ('terribl', 11),
#  ('hide', 11),
#  ('justic', 11),
#  ('ordin', 11),
#  ('terror', 11),
#  ('edom', 11),
#  ('cleans', 11),
#  ('feast', 11),
#  ('slew', 11),
#  ('quicken', 11),
#  ('sharp', 10),
#  ('space', 10),
#  ('remain', 10),
#  ('anoint', 10),
#  ('rebuk', 10),
#  ('uponth', 10),
#  ('torment', 10),
#  ('ofgod', 10),
#  ('untoth', 10),
#  ('reason', 10),
#  ('abund', 10),
#  ('iron', 10),
#  ('devil', 10),
#  ('despis', 10),
#  ('count', 10),
#  ('endur', 10),
#  ('smite', 10),
#  ('egyptian', 10),
#  ('wroth', 10),
#  ('wound', 10),
#  ('causeth', 10),
#  ('doeth', 10),
#  ('glorifi', 10),
#  ('fals', 10),
#  ('vessel', 10),
#  ('dust', 10),
#  ('pilat', 10),
#  ('fierc', 10),
#  ('tenth', 10),
#  ('abid', 10),
#  ('fish', 10),
#  ('agrippa', 10),
#  ('run', 10),
#  ('wave', 10),
#  ('zedekiah', 10),
#  ('breath', 10),
#  ('shadow', 10),
#  ('ephraim', 10),
#  ('saithth', 10),
#  ('prey', 10),
#  ('sake', 10),
#  ('duke', 10),
#  ('visit', 10),
#  ('arch', 10),
#  ('westsid', 10),
#  ('tent', 10),
#  ('needi', 10),
#  ('pitch', 10),
#  ('tender', 10),
#  ('asia', 9),
#  ('wash', 9),
#  ('flame', 9),
#  ('amenth', 9),
#  ('present', 9),
#  ('thechurch', 9),
#  ('fine', 9),
#  ('synagogu', 9),
#  ('need', 9),
#  ('knowest', 9),
#  ('keepeth', 9),
#  ('seat', 9),
#  ('wept', 9),
#  ('sitteth', 9),
#  ('ofhi', 9),
#  ('sixth', 9),
#  ('benjamin', 9),
#  ('lead', 9),
#  ('seventh', 9),
#  ('half', 9),
#  ('incens', 9),
#  ('hail', 9),
#  ('chariot', 9),
#  ('shed', 9),
#  ('sinc', 9),
#  ('andsaid', 9),
#  ('provok', 9),
#  ('gift', 9),
#  ('firstborn', 9),
#  ('swallow', 9),
#  ('bond', 9),
#  ('mark', 9),
#  ('thrust', 9),
#  ('meet', 9),
#  ('resurrect', 9),
#  ('blasphem', 9),
#  ('lament', 9),
#  ('mourn', 9),
#  ('preciou', 9),
#  ('gog', 9),
#  ('husband', 9),
#  ('tell', 9),
#  ('trembl', 9),
#  ('money', 9),
#  ('medit', 9),
#  ('wicked', 9),
#  ('roman', 9),
#  ('purpos', 9),
#  ('coast', 9),
#  ('cock', 9),
#  ('hearken', 9),
#  ('safe', 9),
#  ('stick', 9),
#  ('guard', 9),
#  ('thepeopl', 9),
#  ('nebuchadrezzar', 9),
#  ('upright', 9),
#  ('gloriou', 9),
#  ('separ', 9),
#  ('deal', 9),
#  ('neighbour', 9),
#  ('person', 9),
#  ('uncircumcis', 9),
#  ('heshal', 9),
#  ('taketh', 9),
#  ('theearth', 9),
#  ('buri', 9),
#  ('childrenof', 9),
#  ('blemish', 9),
#  ('astray', 9),
#  ('sworn', 9),
#  ('heritag', 9),
#  ('beseech', 9),
#  ('thyright', 9),
#  ('mercyendureth', 9),
#  ('kindr', 8),
#  ('almighti', 8),
#  ('sawest', 8),
#  ('warn', 8),
#  ('overcometh', 8),
#  ('satan', 8),
#  ('fornic', 8),
#  ('tobe', 8),
#  ('depth', 8),
#  ('strengthen', 8),
#  ('immedi', 8),
#  ('lightn', 8),
#  ('fourth', 8),
#  ('juda', 8),
#  ('himthat', 8),
#  ('join', 8),
#  ('andto', 8),
#  ('red', 8),
#  ('untothem', 8),
#  ('fifth', 8),
#  ('earthquak', 8),
#  ('blow', 8),
#  ('silenc', 8),
#  ('slay', 8),
#  ('vision', 8),
#  ('brimston', 8),
#  ('other', 8),
#  ('street', 8),
#  ('sodom', 8),
#  ('touch', 8),
#  ('soon', 8),
#  ('buy', 8),
#  ('linen', 8),
#  ('least', 8),
#  ('deceiv', 8),
#  ('confus', 8),
#  ('ought', 8),
#  ('quiet', 8),
#  ('chain', 8),
#  ('twelfth', 8),
#  ('pollut', 8),
#  ('bare', 8),
#  ('yield', 8),
#  ('enquir', 8),
#  ('pestil', 8),
#  ('saidunto', 8),
#  ('psalm', 8),
#  ('master', 8),
#  ('next', 8),
#  ('caesar', 8),
#  ('happi', 8),
#  ('besid', 8),
#  ('perceiv', 8),
#  ('driven', 8),
#  ('chang', 8),
#  ('bringeth', 8),
#  ('speaketh', 8),
#  ('oxen', 8),
#  ('distress', 8),
#  ('shake', 8),
#  ('branch', 8),
#  ('search', 8),
#  ('earli', 8),
#  ('deceit', 8),
#  ('prosper', 8),
#  ('theheathen', 8),
#  ('arrow', 8),
#  ('step', 8),
#  ('path', 8),
#  ('sold', 8),
#  ('lot', 8),
#  ('wherebi', 8),
#  ('hamath', 8),
#  ('chaldean', 8),
#  ('spare', 8),
#  ('destruct', 8),
#  ('griev', 8),
#  ('justifi', 8),
#  ('believeth', 8),
#  ('forsaken', 8),
#  ('refug', 8),
#  ('pleas', 8),
#  ('pleasant', 8),
#  ('low', 8),
#  ('forsak', 8),
#  ('spring', 8),
#  ('flourish', 8),
#  ('patienc', 7),
#  ('candlestick', 7),
#  ('pure', 7),
#  ('fatherless', 7),
#  ('tri', 7),
#  ('deed', 7),
#  ('aliv', 7),
#  ('sayest', 7),
#  ('nake', 7),
#  ('eagl', 7),
#  ('wing', 7),
#  ('loveth', 7),
#  ('member', 7),
#  ('thereon', 7),
#  ('weep', 7),
#  ('untohim', 7),
#  ('use', 7),
#  ('likewis', 7),
#  ('kiss', 7),
#  ('read', 7),
#  ('island', 7),
#  ('forehead', 7),
#  ('thanksgiv', 7),
#  ('sir', 7),
#  ('locust', 7),
#  ('serpent', 7),
#  ('almost', 7),
#  ('indign', 7),
#  ('punish', 7),
#  ('remembr', 7),
#  ('fight', 7),
#  ('oftheir', 7),
#  ('isaac', 7),
#  ('top', 7),
#  ('withth', 7),
#  ('miracl', 7),
#  ('learn', 7),
#  ('mad', 7),
#  ('risen', 7),
#  ('theke', 7),
#  ('unclean', 7),
#  ('strang', 7),
#  ('accordingto', 7),
#  ('alon', 7),
#  ('theciti', 7),
#  ('scribe', 7),
#  ('morrow', 7),
#  ('alway', 7),
#  ('question', 7),
#  ('felix', 7),
#  ('brake', 7),
#  ('simon', 7),
#  ('camel', 7),
#  ('dealt', 7),
#  ('exceedingli', 7),
#  ('roundabout', 7),
#  ('kind', 7),
#  ('hang', 7),
#  ('letter', 7),
#  ('servic', 7),
#  ('garden', 7),
#  ('execut', 7),
#  ('bind', 7),
#  ('stream', 7),
#  ('bough', 7),
#  ('multipli', 7),
#  ('thick', 7),
#  ('awak', 7),
#  ('roar', 7),
#  ('spread', 7),
#  ('beauti', 7),
#  ('theland', 7),
#  ('residu', 7),
#  ('ofman', 7),
#  ('magnifi', 7),
#  ('sown', 7),
#  ('corn', 7),
#  ('think', 7),
#  ('plead', 7),
#  ('bashan', 7),
#  ('trespass', 7),
#  ('threshold', 7),
#  ('afterward', 7),
#  ('keeper', 7),
#  ('homer', 7),
#  ('jordan', 7),
#  ('preserv', 7),
#  ('palac', 7),
#  ('satisfi', 7),
#  ('covet', 7),
#  ('excel', 7),
#  ('knowledg', 7),
#  ...]

# %%
print(len(df))
# Out:
# 4517

# %%
import matplotlib.pyplot as plt
x, y = zip(*terms_freq)
plt.xticks(rotation=90)
plt.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14856/3664112681.py in <module>
#       3 plt.xticks(rotation=90)
#       4 plt.plot(x, y)
# ----> 5 plt.show()
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     387     """
#     388     _warn_if_gui_out_of_main_thread()
# --> 389     return _get_backend_mod().show(*args, **kwargs)
#     390
#     391
#
# ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295                     self.figure.draw(renderer)
#    2296
#    2297             if bbox_inches:
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2835
#    2836             self.patch.draw(renderer)
# -> 2837             mimage._draw_list_compositing_images(
#    2838                 renderer, self, artists, self.suppressComposite)
#    2839
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3089             renderer.stop_rasterizing()
#    3090
# -> 3091         mimage._draw_list_compositing_images(
#    3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1157
#    1158         ticks_to_draw = self._update_ticks()
# -> 1159         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1160                                                                 renderer)
#    1161
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1083     def _get_tick_bboxes(self, ticks, renderer):
#    1084         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085         return ([tick.label1.get_window_extent(renderer)
#    1086                  for tick in ticks if tick.label1.get_visible()],
#    1087                 [tick.label2.get_window_extent(renderer)
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1083     def _get_tick_bboxes(self, ticks, renderer):
#    1084         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085         return ([tick.label1.get_window_extent(renderer)
#    1086                  for tick in ticks if tick.label1.get_visible()],
#    1087                 [tick.label2.get_window_extent(renderer)
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     908
#     909         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 910             bbox, info, descent = self._get_layout(self._renderer)
#     911             x, y = self.get_unitless_position()
#     912             x, y = self.get_transform().transform((x, y))
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     307
#     308         # Full vertical extent of font, including ascenders and descenders:
# --> 309         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     310             "lp", self._fontproperties,
#     311             ismath="TeX" if self.get_usetex() else False)
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     268         flags = get_hinting_flag()
#     269         font = self._get_agg_font(prop)
# --> 270         font.set_text(s, 0.0, flags=flags)
#     271         w, h = font.get_width_height()  # width and height of unrotated string
#     272         d = font.get_descent()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create function to remove punctuation, tokenize, remove stopwords, and stem

# %%
### Create function to remove punctuation, tokenize, remove stopwords, and stem

def clean_text(text):
    text = "".join([word.lower() for word in text if word not in string.punctuation])
     #tokens = re.split('\W+', text)
    tokens = word_tokenize(text)
    text = " ".join([ps.stem(word) for word in tokens if word not in stopwords_En])
    return text
df=df[['verse','context']]
df['cleaned_text'] = df['context'].apply(lambda x: clean_text(x))
df.head(10)

# %% [markdown]
# ## 2. Vectorizing text data

# %%
sentences = ["good movie", "not a good movie", "did not like", "i like it"]

# %% [markdown]
# ### 2.1: Count vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
features_cv = vectorizer.fit_transform(sentences)  #Sparse Matrix

print(features_cv.shape)
print('Sparse Matrix :\n', features_cv)

features_cv = pd.DataFrame(features_cv.toarray())
features_cv.columns = vectorizer.get_feature_names()
features_cv

# %%
from sklearn.feature_extraction.text import CountVectorizer

# To create a Count Vectorizer, we simply need to instantiate one.
# There are special parameters we can set here when making the vectorizer, but
# for the most basic example, it is not needed.


vectorizer = CountVectorizer()
features_CountVec = vectorizer.fit_transform(df['cleaned_text'])  #Sparse_Matrix
print(features_CountVec.shape)
print('Sparse_Matrix :\n', features_CountVec)

# كان----- sparce matrice------ حولناها ل ماتريس عادىة----
features_CountVec = pd.DataFrame(features_CountVec.toarray())
features_CountVec.columns = vectorizer.get_feature_names()
features_CountVec

# %% [markdown]
# ### 4.2.2: Vectorizing Data: N-Grams

# %%
# ngram = term -> 2terms -> 3terms
ngram_vect = CountVectorizer(ngram_range=(1,3))
features_ngram = ngram_vect.fit_transform(df['cleaned_text'])

print(features_ngram.shape)
print('Sparse Matrix :\n', features_ngram)

features_ngram = pd.DataFrame(features_ngram.toarray())
features_ngram.columns = ngram_vect.get_feature_names()
features_ngram

# %%
# الفرق بيناتهم انك تحسب وزن الكلمة و ليس عدد التكررا فقط
#  w = TF * IDF

# %% [markdown]
# ### 4.2.3: Vectorizing Raw Data: TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

#tfidf = TfidfVectorizer(min_df=1)
tfidf = TfidfVectorizer( ngram_range=(2,2))
features_tfidf = tfidf.fit_transform(df['cleaned_text'])

print(features_tfidf.shape)
print('Sparse Matrix :\n', features_tfidf)

features_tfidf = pd.DataFrame(features_tfidf.toarray())
features_tfidf.columns = tfidf.get_feature_names()
features_tfidf.head(10)
